# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# This code loads the dependencies and imports my api key for google.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# I load the csv and deleted the unnecessary date column to make analysis easier.
weather_df = pd.read_csv('../WeatherPy/city_weather.csv')
weather_df.drop(columns=('Date'), inplace=True)
weather_df
# Out:
#                City  Longitude  Latitude  Max Temp  Humidity  Wind Speed  \
# 0        Butaritari     172.79      3.07     82.58      71.0        8.34
# 1            Albany     -73.97     42.60     72.00      58.0        3.27
# 2    Port Elizabeth      25.57    -33.92     60.80      59.0       17.22
# 3           Ushuaia     -68.30    -54.80     32.00      83.0        3.36
# 4           Rikitea    -134.97    -23.12     66.31      62.0       17.92
# ..              ...        ...       ...       ...       ...         ...
# 547       Ambovombe      46.08    -25.17     63.12      70.0       12.59
# 548  Saint-Augustin     -58.65     51.23     65.46      54.0        8.66
# 549           Konde      39.75     -4.95     75.13      77.0       11.70
# 550          Vilcún     -72.23    -38.65     46.40     100.0        4.70
# 551           Quryq      51.65     43.20     78.37      61.0        8.70
#
#      Cloudiness Country
# 0          54.0      KI
# 1          41.0      US
# 2           0.0      ZA
# 3           0.0      AR
# 4           0.0      PF
# ..          ...     ...
# 547         7.0      MG
# 548        69.0      CA
# 549       100.0      TZ
# 550        75.0      CL
# 551       100.0      KZ
#
# [552 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# This code adds a heatmap. I set the point radius at 2 because I thought it gave a better visualization focused on the cities and vacation destinations. But a larger
# radius would give a more encompassing picture of the heatmap while losing some specificity. N.B. I just downloaded and saved the fig manually. To automate that 
# process I could however have exported it to html with something like "embed_minimal_html('heat_map.html', views=[fig])".

from ipywidgets.embed import embed_minimal_html

locations = weather_df[['Latitude', 'Longitude']]
weightings = weather_df['Humidity']
fig = gmaps.figure(center= (0,0), zoom_level=2.0)

heat_layer = gmaps.heatmap_layer(locations, weights=weightings, 
                                 dissipating=False, max_intensity=100, point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# To find ideal weather we simply use a loc function to sort the database by weather between 70 and 80 with a low wind speed and low cloudiness factor.
ideal_weather = weather_df.loc[(weather_df['Max Temp'] > 70 ) & (weather_df['Max Temp'] < 80) & (weather_df['Wind Speed'] < 10) & 
                               (weather_df['Cloudiness'] < 10)].reset_index(drop=True)
ideal_weather.head()
# This line just follows the suggestion of the homework by dropping any null values and then creating a new df called hotel_df that has the locations to find hotels.
hotel_df = ideal_weather.dropna()
hotel_df
# Out:
#                        City  Longitude  Latitude  Max Temp  Humidity  \
# 0           Tiznit Province      -9.50     29.58     73.36      51.0
# 1             Niagara Falls     -79.07     43.10     71.60      77.0
# 2                    Vostok     135.88     46.49     78.39      47.0
# 3                 Nantucket     -70.10     41.28     71.60      88.0
# 4                     Bāneh      45.89     36.00     75.49      21.0
# 5                   Corumbá     -57.65    -19.01     71.46      49.0
# 6                    Bethel     -73.41     41.37     75.99      78.0
# 7                Marsaxlokk      14.54     35.84     75.00      94.0
# 8                     Khāsh      61.22     28.22     75.27      62.0
# 9                  La Palma    -118.05     33.85     75.20      57.0
# 10          Yangi Marg`ilon      71.72     40.43     71.60      53.0
# 11                    Sirte      16.59     31.21     74.34      70.0
# 12                  Ashland     -82.27     40.82     72.00      94.0
# 13               Vila Velha     -40.29    -20.33     73.99      88.0
# 14             Rapid Valley    -103.15     44.06     77.00      56.0
# 15                    Gairo       9.50     39.85     71.60      88.0
# 16                    Airai     125.41     -8.93     71.37      49.0
# 17                   Pauini     -66.98     -7.71     72.23      57.0
# 18    Chapada dos Guimarães     -55.75    -15.46     75.20      44.0
# 19               Dzidzantun     -89.05     21.25     77.00      83.0
# 20                 Hannibal     -91.36     39.71     73.99      94.0
# 21                     Mayo     -76.51     38.89     79.00      83.0
# 22              Novyy Urgal     132.56     51.07     79.99      42.0
# 23                   Samaná     -69.34     19.21     79.32      84.0
# 24  Santa Cruz de la Sierra     -63.17    -17.80     75.20      78.0
#
#     Wind Speed  Cloudiness Country
# 0         1.79         0.0      MA
# 1         3.36         1.0      CA
# 2         5.44         0.0      RU
# 3         5.82         1.0      US
# 4         3.09         1.0      IR
# 5         2.77         0.0      BR
# 6         3.36         1.0      US
# 7         4.70         0.0      MT
# 8         1.01         0.0      IR
# 9         5.82         1.0      US
# 10        6.93         0.0      UZ
# 11        6.93         0.0      LY
# 12        6.93         1.0      US
# 13        3.36         5.0      BR
# 14        8.05         1.0      US
# 15        4.70         5.0      IT
# 16        5.57         4.0      TL
# 17        0.29         8.0      BR
# 18        2.24         0.0      BR
# 19        3.44         0.0      MX
# 20        4.70         1.0      US
# 21        6.93         1.0      US
# 22        2.13         0.0      RU
# 23        8.59         1.0      DO
# 24        9.17         6.0      BO

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# This code does a query search and then selects the first hit of the query by taking the results. Results[0]['name'] gives the first item in the list. The json results
# is essentially a list of dictionary items. Chained indexing is not the best in Pandas, although it works in this case. But I would be tempted to use json_normalize
# to create a new dataframe of this data if it was needed. But the likelihood for error is less simply getting the first item in a list in a relatively simply query.

for index, row in hotel_df.iterrows():
     
    try:
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        hotel_locations = f"{row.loc['Latitude']}, {row.loc['Longitude']}"
        params = {
            "location": hotel_locations,
            'radius': 5000,
            "type": "lodging",
            "key": g_key,
            }
    
        response = requests.get(base_url, params=params).json()
        results = response['results']
        
        # This code stores the name and location of the hotels as variables so they can be added to the hotel_df
        hotel_name = results[0]['name']
        hotel_lat = results[0]['geometry']['location']['lat']
        hotel_lng = results[0]['geometry']['location']['lng']
        
        hotel_df.loc[index, 'Hotel Name'] = hotel_name
        hotel_df.loc[index, 'Hotel Lat'] = hotel_lat
        hotel_df.loc[index, 'Hotel Lng'] = hotel_lng
        
        print(f"The lodging place is {hotel_name} and its location is (Lat/Lng): {hotel_lat}, {hotel_lng}")
                
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Missing field/result... skipping.
# ------------
# The lodging place is Sheraton on the Falls Hotel and its location is (Lat/Lng): 43.0908047, -79.0730234
# ------------
# Missing field/result... skipping.
# ------------
# The lodging place is Jared Coffin House and its location is (Lat/Lng): 41.2851893, -70.10078659999999
# ------------
# The lodging place is ساختمان زیتون and its location is (Lat/Lng): 35.99829959999999, 45.8819861
# ------------
# The lodging place is Hotel Laura Vicunha and its location is (Lat/Lng): -19.002699, -57.6495638
# ------------
# The lodging place is Courtyard by Marriott Danbury and its location is (Lat/Lng): 41.4113711, -73.4152646
# ------------
# The lodging place is Water's Edge and its location is (Lat/Lng): 35.8238278, 14.5291556
# ------------
# The lodging place is دفتر پیشخوان دولت جمال زهی (خالد) and its location is (Lat/Lng): 28.2171113, 61.21680399999999
# ------------
# The lodging place is La Quinta Inn & Suites by Wyndham Buena Park and its location is (Lat/Lng): 33.8604545, -118.0315539
# ------------
# The lodging place is Ikathouse and its location is (Lat/Lng): 40.4614177, 71.7283138
# ------------
# The lodging place is City Hotel and its location is (Lat/Lng): 31.20643780000001, 16.5889102
# ------------
# The lodging place is Holiday Inn Express & Suites Ashland and its location is (Lat/Lng): 40.8592771, -82.2687095
# ------------
# The lodging place is Hotel Vitória Palace and its location is (Lat/Lng): -20.3058612, -40.2962234
# ------------
# The lodging place is Fairfield Inn & Suites by Marriott Rapid City and its location is (Lat/Lng): 44.098401, -103.1489259
# ------------
# The lodging place is Iradas Domo - Affittacamere and its location is (Lat/Lng): 39.8830515, 9.532155099999997
# ------------
# The lodging place is Juvinal Martin and its location is (Lat/Lng): -8.930576, 125.396797
# ------------
# The lodging place is Casa do Kiwliks and its location is (Lat/Lng): -7.707842999999998, -66.9976112
# ------------
# The lodging place is Pousada Morro Dos Ventos and its location is (Lat/Lng): -15.4633352, -55.7482505
# ------------
# The lodging place is Hacienda San Francisco Tzacalha and its location is (Lat/Lng): 21.2510971, -89.0258619
# ------------
# The lodging place is Country Hearth Inn Hannibal and its location is (Lat/Lng): 39.7135646, -91.3628243
# ------------
# The lodging place is Resorts Resource Group International and its location is (Lat/Lng): 38.92248, -76.5209612
# ------------
# Missing field/result... skipping.
# ------------
# The lodging place is The Bannister - Hotel & Yacht Club and its location is (Lat/Lng): 19.194865, -69.355311
# ------------
# The lodging place is Hotel Cortez and its location is (Lat/Lng): -17.770927, -63.18414499999999
# ------------

# %%
# This code drops cities where no hotel info was found within the search radius. I then reset the index to get the final database. 
hotel_df.dropna(inplace=True)
hotel_df.reset_index(drop=True)
# Out:
#                        City  Longitude  Latitude  Max Temp  Humidity  \
# 0             Niagara Falls     -79.07     43.10     71.60      77.0
# 1                 Nantucket     -70.10     41.28     71.60      88.0
# 2                     Bāneh      45.89     36.00     75.49      21.0
# 3                   Corumbá     -57.65    -19.01     71.46      49.0
# 4                    Bethel     -73.41     41.37     75.99      78.0
# 5                Marsaxlokk      14.54     35.84     75.00      94.0
# 6                     Khāsh      61.22     28.22     75.27      62.0
# 7                  La Palma    -118.05     33.85     75.20      57.0
# 8           Yangi Marg`ilon      71.72     40.43     71.60      53.0
# 9                     Sirte      16.59     31.21     74.34      70.0
# 10                  Ashland     -82.27     40.82     72.00      94.0
# 11               Vila Velha     -40.29    -20.33     73.99      88.0
# 12             Rapid Valley    -103.15     44.06     77.00      56.0
# 13                    Gairo       9.50     39.85     71.60      88.0
# 14                    Airai     125.41     -8.93     71.37      49.0
# 15                   Pauini     -66.98     -7.71     72.23      57.0
# 16    Chapada dos Guimarães     -55.75    -15.46     75.20      44.0
# 17               Dzidzantun     -89.05     21.25     77.00      83.0
# 18                 Hannibal     -91.36     39.71     73.99      94.0
# 19                     Mayo     -76.51     38.89     79.00      83.0
# 20                   Samaná     -69.34     19.21     79.32      84.0
# 21  Santa Cruz de la Sierra     -63.17    -17.80     75.20      78.0
#
#     Wind Speed  Cloudiness Country  \
# 0         3.36         1.0      CA
# 1         5.82         1.0      US
# 2         3.09         1.0      IR
# 3         2.77         0.0      BR
# 4         3.36         1.0      US
# 5         4.70         0.0      MT
# 6         1.01         0.0      IR
# 7         5.82         1.0      US
# 8         6.93         0.0      UZ
# 9         6.93         0.0      LY
# 10        6.93         1.0      US
# 11        3.36         5.0      BR
# 12        8.05         1.0      US
# 13        4.70         5.0      IT
# 14        5.57         4.0      TL
# 15        0.29         8.0      BR
# 16        2.24         0.0      BR
# 17        3.44         0.0      MX
# 18        4.70         1.0      US
# 19        6.93         1.0      US
# 20        8.59         1.0      DO
# 21        9.17         6.0      BO
#
#                                        Hotel Name  Hotel Lat   Hotel Lng
# 0                     Sheraton on the Falls Hotel  43.090805  -79.073023
# 1                              Jared Coffin House  41.285189  -70.100787
# 2                                   ساختمان زیتون  35.998300   45.881986
# 3                             Hotel Laura Vicunha -19.002699  -57.649564
# 4                   Courtyard by Marriott Danbury  41.411371  -73.415265
# 5                                    Water's Edge  35.823828   14.529156
# 6               دفتر پیشخوان دولت جمال زهی (خالد)  28.217111   61.216804
# 7    La Quinta Inn & Suites by Wyndham Buena Park  33.860455 -118.031554
# 8                                       Ikathouse  40.461418   71.728314
# 9                                      City Hotel  31.206438   16.588910
# 10           Holiday Inn Express & Suites Ashland  40.859277  -82.268709
# 11                           Hotel Vitória Palace -20.305861  -40.296223
# 12  Fairfield Inn & Suites by Marriott Rapid City  44.098401 -103.148926
# 13                    Iradas Domo - Affittacamere  39.883052    9.532155
# 14                                 Juvinal Martin  -8.930576  125.396797
# 15                                Casa do Kiwliks  -7.707843  -66.997611
# 16                       Pousada Morro Dos Ventos -15.463335  -55.748250
# 17                Hacienda San Francisco Tzacalha  21.251097  -89.025862
# 18                    Country Hearth Inn Hannibal  39.713565  -91.362824
# 19           Resorts Resource Group International  38.922480  -76.520961
# 20             The Bannister - Hotel & Yacht Club  19.194865  -69.355311
# 21                                   Hotel Cortez -17.770927  -63.184145

# %%
# This code replots the map and adds the appropriate map markers with an info_box_template that gives the Hotel name, city and country. 

locations = weather_df[['Latitude', 'Longitude']]
hotel_locations = hotel_df[['Hotel Lat', 'Hotel Lng']]
weightings = weather_df['Humidity']

fig = gmaps.figure(center= (0,0), zoom_level=2.2)
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
marker_layer = gmaps.marker_layer(hotel_locations, info_box_content=hotel_info)

heat_layer = gmaps.heatmap_layer(locations, weights=weightings,
                                 dissipating=False, max_intensity=100, point_radius = 2)


fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
